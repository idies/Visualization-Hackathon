# %%
import pickle
import geopandas as gpd
import pandas as pd
import os

# %%
gdf = pickle.load(open('baltimore.pkl', 'rb'))

# %%
gdf
# Out:
#                             key                category  \
# 0                           44B    legislative_district
# 1                         21216                 zipcode
# 2                         21217                 zipcode
# 3                         21213                 zipcode
# 4                         21207                 zipcode
# 5                            41    legislative_district
# 6                             2  congressional_district
# 7                         21218                 zipcode
# 8                         21211                 zipcode
# 9                            45    legislative_district
# 10                        21206                 zipcode
# 11                        21237                 zipcode
# 12                           43    legislative_district
# 13                        21215                 zipcode
# 14                        21251                 zipcode
# 15                        21214                 zipcode
# ...
